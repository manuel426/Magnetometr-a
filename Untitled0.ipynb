# %%
#Tarea Geofísica
#Datos de Magnetometría
#Manuel Ariza Fuentes
#201125554
# %pylab inline  
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Grupo A

# %%
#Cargando las matrices de los datos de Magnetometría del grupo A. Son 3 cuadriculas de datos. Las últimas dos lineas son en el mismo lugar
A1=loadtxt("survey1_magnetometria_RoverData.txt")
A2=loadtxt("survey1_magnetometria_RoverData2.txt")
A3=loadtxt("survey2-3_magnetometria_RoverData.txt")

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
x1=A1[:,0]
y1=A1[:,1]
mag1=A1[:,2]

x2=A2[:,0]
y2=A2[:,1]
mag2=A2[:,2]

x3=A3[:,0]
y3=A3[:,1]
mag3=A3[:,2]

# %%
#Cuadriculas de cada Linea
#Linea 1
scatter(x1,y1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo A')

# %%
#Linea 2
scatter(x2,y2)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 2, Grupo A')

# %%
#Linea 3
scatter(x3,y3)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 3, Grupo A')

# %% [markdown]
# #### Esta linea se realizó en las coordenadas 4°59'31''N 74°54'56''W, en el mapa corresponden a depositos del cuaternario, depositados tal vez por algun
# afluente del rio Magdalena, el cual está cerca de la zona. En los datos no se observan grandes cambios, excepto un cero, que posiblemente es un dato
# de ruido. En general tiene susceptibilidad magnética alta, probablemente la proveniencia de estas rocas es ígneo, con lo cual los depositos del cuaternario
# pueden contener magnetitas o hematitas (minerales con alta susceptibilidad magnetica).

# %%
grafica1 = plt.figure(figsize=(10,8))
grafica1n = grafica1.gca(projection='3d')
ploteo1=grafica1n.plot_trisurf(x1,y1,mag1, cmap=plt.cm.RdYlGn)
grafica1n.set_zlabel('nanoTeslas (nT)')
grafica1n.set_title('Campo Magnetico')

# %%
grafica2 = plt.figure(figsize=(10,8))
grafica2n = grafica1.gca(projection='3d')
ploteo2=grafica2n.plot_trisurf(x2,y2,mag2, cmap=plt.cm.RdYlGn)
grafica2n.set_zlabel('nanoTeslas (nT)')
grafica2n.set_title('Campo Magnetico')

# %%
grafica3 = plt.figure(figsize=(10,8))
grafica3n = grafica1.gca(projection='3d')
ploteo3=grafica3n.plot_trisurf(x3,y3,mag3, cmap=plt.cm.RdYlGn)
grafica3n.set_zlabel('nanoTeslas (nT)')
grafica3n.set_title('Campo Magnetico')

# %% [markdown]
# # Grupo E

# %% [markdown]
# # Grupo I

# %%
#Cargando las matrices de los datos de Magnetometría del grupo I. Es 1 cuadricula de datos.
I1=loadtxt("Survey_Grupo_I.txt")

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
xi1=I1[:,0]
yi1=I1[:,1]
magi1=I1[:,2]

# %%
#Cuadricula de la linea
#Linea 1
scatter(xi1,yi1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo I')

# %%
grafica4 = plt.figure(figsize=(10,8))
grafica4n = grafica4.gca(projection='3d')
ploteo4=grafica4n.plot_trisurf(xi1,yi1,magi1, cmap=plt.cm.RdYlGn)
grafica4n.set_zlabel('nanoTeslas (nT)')
grafica4n.set_title('Campo Magnetico')

# %% [markdown]
# #### La transecta está en las coordenas:5°7'18.65" N 74°56'4.38 W. En estas coordenadas, el mapa geológico es de esquistos verdes, que son metamorfismo proveniente del complejo Cajamarca. Es decir, que son metabasitas, (basalto metamorfico), y el basalto al ser una roca máfica suele tener minerales con alto contenido de hierro, el cual es un elemento que causa que los minerales tengan altas susceptibilidades magnéticas.

# %% [markdown]
# # Grupo H

# %%
#Cargando las matrices de los datos de Magnetometría del grupo I. Es 1 cuadricula de datos.
H1=loadtxt("Survey_GrupoH.txt")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-129-cdb04f1dd921> in <module>()
#       1 #Cargando las matrices de los datos de Magnetometría del grupo I. Es 1 cuadricula de datos.
# ----> 2 H1=loadtxt("Survey_GrupoH.txt")
#
# /usr/lib64/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     727                 fh = iter(bz2.BZ2File(fname))
#     728             else:
# --> 729                 fh = iter(open(fname, 'U'))
#     730         else:
#     731             fh = iter(fname)
#
# IOError: [Errno 2] No such file or directory: 'Survey_GrupoH.txt'

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
xh1=H1[:,0]
yh1=H1[:,1]
magh1=H1[:,2]

# %%
#Cuadricula de la linea
#Linea 1
scatter(xh1,yh1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo I')
