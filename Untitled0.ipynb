# %%
#Tarea Geofísica
#Datos de Magnetometría
#Manuel Ariza Fuentes
#201125554
# %pylab inline  
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Grupo A

# %%
#Cargando las matrices de los datos de Magnetometría del grupo A. Son 3 cuadriculas de datos. Las últimas dos lineas son en el mismo lugar
A1=loadtxt("survey1_magnetometria_RoverData.txt")
A2=loadtxt("survey1_magnetometria_RoverData2.txt")
A3=loadtxt("survey2-3_magnetometria_RoverData.txt")

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
x1=A1[:,0]
y1=A1[:,1]
mag1=A1[:,2]

x2=A2[:,0]
y2=A2[:,1]
mag2=A2[:,2]

x3=A3[:,0]
y3=A3[:,1]
mag3=A3[:,2]

# %%
#Cuadriculas de cada Linea
#Linea 1
scatter(x1,y1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo A')

# %%
#Linea 2
scatter(x2,y2)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 2, Grupo A')

# %%
#Linea 3
scatter(x3,y3)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 3, Grupo A')

# %% [markdown]
# #### Esta linea se realizó en las coordenadas 4°59'31''N 74°54'56''W, en el mapa corresponden a depositos del cuaternario, depositados tal vez por algun
# afluente del rio Magdalena, el cual está cerca de la zona. En los datos no se observan grandes cambios, excepto un cero, que posiblemente es un dato
# de ruido. En general tiene susceptibilidad magnética alta, probablemente la proveniencia de estas rocas es ígneo, con lo cual los depositos del cuaternario
# pueden contener magnetitas o hematitas (minerales con alta susceptibilidad magnetica).

# %%
grafica1 = plt.figure(figsize=(10,8))
grafica1n = grafica1.gca(projection='3d')
ploteo1=grafica1n.plot_trisurf(x1,y1,mag1, cmap=plt.cm.RdYlGn)
grafica1n.set_zlabel('Teslas (T)')
grafica1n.set_title('Campo Magnetico, Linea 1, grupo A')

# %%
grafica2 = plt.figure(figsize=(10,8))
grafica2n = grafica2.gca(projection='3d')
ploteo2=grafica2n.plot_trisurf(x2,y2,mag2, cmap=plt.cm.RdYlGn)
grafica2n.set_zlabel('Teslas (T)')
grafica2n.set_title('Campo Magnetico, Linea 2, grupo A')

# %% [markdown]
# #### Por alguna razón, los datos dos lineas de los archivos estan repetidos

# %%
grafica3 = plt.figure(figsize=(10,8))
grafica3n = grafica3.gca(projection='3d')
ploteo3=grafica3n.plot_trisurf(x3,y3,mag3, cmap=plt.cm.RdYlGn)
grafica3n.set_zlabel('Teslas (T)')
grafica3n.set_title('Campo Magnetico, Linea 3, grupo A')

# %% [markdown]
# #### La grafica esta rara, hay varias oscilaciones del campo en nanoteslas, desde altos nanoteslas hasta cero, indicando que hay errores en la medicion

# %% [markdown]
# # Grupo E

# %%
#Cargando las matrices de los datos de Magnetometría del grupo A. Son 3 cuadriculas de datos. Las últimas dos lineas son en el mismo lugar
E1=loadtxt("Survey1_grupo_E.txt")
E2=loadtxt("Survey2_Grupo_E.txt")
E3=loadtxt("Survey3_grupo_E.txt")
E4=loadtxt("Survey4_Grupo_E.txt")

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
xe1=E1[:,0]
ye1=E1[:,1]
mage1=E1[:,2]

xe2=E2[:,0]
ye2=E2[:,1]
mage2=E2[:,2]

xe3=E3[:,0]
ye3=E3[:,1]
mage3=E3[:,2]

xe4=E4[:,0]
ye4=E4[:,1]
mage4=E4[:,2]

# %%
#Cuadriculas de cada Linea
#Linea 1
scatter(xe1,ye1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo E')

# %%
#Cuadriculas de cada Linea
#Linea 2
scatter(xe2,ye2)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 2, Grupo E')

# %%
#Cuadriculas de cada Linea
#Linea 3
scatter(xe2,ye2)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 3, Grupo E')

# %%
#Cuadriculas de cada Linea
#Linea 4
scatter(xe4,ye4)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 4, Grupo E')

# %%
De las cuatro graficas, solo una es una cuadricula, la otra son lineas, que a la larga no sirven, porque se necesita ver su variacion en
tres dimensiones. Sólo se va a hacer la primer linea en 3 dimensiones.

# %%
grafica6 = plt.figure(figsize=(10,8))
grafica6n = grafica6.gca(projection='3d')
ploteo6=grafica6n.plot_trisurf(xe1,ye1,mage1, cmap=plt.cm.RdYlGn)
grafica6n.set_zlabel('nanoTeslas (nT)')
grafica6n.set_title('Campo Magnetico, Linea 1, grupo A')

# %% [markdown]
# #### Debido a que no hay coordenadas de esta cuadricula, no se puede saber la geologia del lugar. Pero se puede observar que hacia la esquina
# superior izquierda hay un aumento de campo magnetico, ademas de que hay una anomalia que baja mucho. Probablemente, hay un cambio fuerte en
# litología, ó simplemente hay un cuerpo fracturado o fallado, que no permite la contiunuidad de la medición de la
# susceptibildiad magnética.

# %% [markdown]
# # Grupo I

# %%
#Cargando las matrices de los datos de Magnetometría del grupo I. Es 1 cuadricula de datos.
I1=loadtxt("Survey_Grupo_I.txt")

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
xi1=I1[:,0]
yi1=I1[:,1]
magi1=I1[:,2]

# %%
#Cuadricula de la linea
#Linea 1
scatter(xi1,yi1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo I')

# %%
grafica4 = plt.figure(figsize=(10,8))
grafica4n = grafica4.gca(projection='3d')
ploteo4=grafica4n.plot_trisurf(xi1,yi1,magi1, cmap=plt.cm.RdYlGn)
grafica4n.set_zlabel('Teslas (T)')
grafica4n.set_title('Campo Magnetico, grupo I')

# %% [markdown]
# #### La transecta está en las coordenas:5°7'18.65" N 74°56'4.38 W. En estas coordenadas, el mapa geológico es de esquistos verdes,
#     que son metamorfismo proveniente del complejo Cajamarca. Es decir, que son metabasitas, (basalto metamorfico), y el basalto
#     al ser una roca máfica suele tener minerales con alto contenido de hierro, el cual es un elemento que causa que los minerales
#     tengan altas susceptibilidades magnéticas. Hay varios picos, que son mas probables de que sean ruido a que sean algo importante.

# %% [markdown]
# # Grupo H

# %%
#Cargando las matrices de los datos de Magnetometría del grupo I. Es 1 cuadricula de datos.
H1=loadtxt("Survey_Grupo_H.txt")

# %%
#Cargando los vectores X,Y y campo magnético en nanoteslas, de las matrices:
xh1=H1[:,0]
yh1=H1[:,1]
magh1=H1[:,2]

# %%
#Cuadricula de la linea
#Linea 1
scatter(xh1,yh1)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Linea 1, Grupo I')

# %%
grafica5 = plt.figure(figsize=(10,8))
grafica5n = grafica5.gca(projection='3d')
ploteo5=grafica5n.plot_trisurf(xh1,yh1,magh1, cmap=plt.cm.RdYlGn)
grafica5n.set_zlabel('nanoTeslas (nT)')
grafica5n.set_title('Campo Magnetico, grupo H')

# %%
La transecta se hizo en las coordenadas: 4°58'39''N 74°54'42''W,en el mapa geológico
corresponden a depositos del cuaternario, depositados tal vez por algun afluente del rio Magdalena, el cual está cerca de la zona.
En los datos no se observan grandes cambios, excepto un pico de 32400 nanoteslas, lo cual es probablemente ruido. En general tiene susceptibilidad 
magnética alta, probablemente la proveniencia de estas rocas es ígneo, con lo cual los depositos del cuaternario pueden contener magnetitas o hematitas 
(minerales con alta susceptibilidad magnetica).
